# %%
import yt
ds = yt.load("/Users/iani/Downloads/enzo_tiny_cosmology/DD0046/DD0046")
print ("Redshift =", ds.current_redshift)
p = yt.ProjectionPlot(ds, "y", "density")
p.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2017-02-27 19:39:36,704 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2017-02-27 19:39:36,701 ylim = 0.000000 1.000000
# yt : [INFO     ] 2017-02-27 19:39:36,700 xlim = 0.000000 1.000000
# yt : [INFO     ] 2017-02-27 19:39:36,698 ylim = 0.000000 1.000000
# yt : [INFO     ] 2017-02-27 19:39:36,696 xlim = 0.000000 1.000000
# yt : [INFO     ] 2017-02-27 19:39:36,695 Projection completed
# yt : [INFO     ] 2017-02-27 19:39:35,108 Gathering a field list (this may take a moment.)
# ...
# Parsing Hierarchy :   0%|          | 0/211 [00:00<?, ?it/s]
# -2.7810863612032e-09
# Redshift =
# yt : [INFO     ] 2017-02-27 19:39:35,063 Parameters: hubble_constant           = 0.702
# yt : [INFO     ] 2017-02-27 19:39:35,061 Parameters: omega_matter              = 0.273
# yt : [INFO     ] 2017-02-27 19:39:35,060 Parameters: omega_lambda              = 0.727
# ...
